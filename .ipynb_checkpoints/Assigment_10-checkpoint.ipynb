# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("adult.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-58b38601bc8c> in <cell line: 1>()
# ----> 1 df=pd.read_csv("adult.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
#1.Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
#2. Check Last 10 Rows of The Dataset
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
#3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
print("Number of Rows" , df.shape[0])
print("Number of Columns" , df.shape[1])
# Out:
# Number of Rows 48842
# Number of Columns 15

# %%
#4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
#5.Check Null Values And Also Create A Heatmap In The Dataset

# %%
df.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
#Heatmap

# %%
#6. Fetch Random Sample From the Dataset (50%)

# %%
random_sample=df.sample(frac=0.5)

# %%
random_sample
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 9165    43       Private  343121  Some-college               10
# 37157   46       Private  196858       Masters               14
# 27176   22     State-gov  121471     Bachelors               13
# 39851   47     Local-gov  228372       Masters               14
# 36627   34       Private  300681  Some-college               10
# ...    ...           ...     ...           ...              ...
# 14867   21       Private   39182    Assoc-acdm               12
# 30330   38       Private  117528     Bachelors               13
# 5790    37  Self-emp-inc  198841     Bachelors               13
# 12019   30       Private  170412  Some-college               10
# 41066   49       Private   98010     Bachelors               13
#
#            marital-status         occupation    relationship   race  gender  \
# 9165             Divorced      Other-service   Not-in-family  White  Female
# ...

# %%
#7. Perform Data Cleaning [Replace'?' with NaN]

# %%
replace=df.replace("?",np.nan)

# %%
replace
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#8. Drop All The Missing Values

# %%
print(df.isnull().sum())
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df=df.dropna()
df.count()
# Out:
# age                48842
# workclass          48842
# fnlwgt             48842
# education          48842
# educational-num    48842
# marital-status     48842
# occupation         48842
# relationship       48842
# race               48842
# gender             48842
# capital-gain       48842
# capital-loss       48842
# hours-per-week     48842
# native-country     48842
# income             48842
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
#9. Check Duplicate Data and Drop Them

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Length: 48842, dtype: bool

# %%
df[df.duplicated()]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 864     24           Private  194630     Bachelors               13
# 11189   37           Private   52870     Bachelors               13
# 11212   29           Private   36440     Bachelors               13
# 13848   30           Private  180317     Assoc-voc               11
# 15960   18      Self-emp-inc  378036          12th                8
# 18476   39           Private  184659       HS-grad                9
# 19399   19           Private  130431       5th-6th                3
# 19726   41           Private  116391     Bachelors               13
# 20606   25           Private  308144     Bachelors               13
# 21162   25           Private  308144     Bachelors               13
# 21385   90           Private   52386  Some-college               10
# 24361   21           Private  243368     Preschool                1
# 25189   29                 ?   41281     Bachelors               13
# ...

# %%
duplicate_data_df=df[df.duplicated]

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#10. Get Overall Statistics About The Dataframe

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48790.000000  4.879000e+04     48790.000000  48790.000000
# mean      38.652798  1.896690e+05        10.078807   1080.217688
# std       13.708493  1.056172e+05         2.570046   7455.905921
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175550e+05         9.000000      0.000000
# 50%       37.000000  1.781385e+05        10.000000      0.000000
# 75%       48.000000  2.376062e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48790.000000    48790.000000
# mean      87.595573       40.425886
# std      403.209129       12.392729
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.describe(include="all")
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   48790.000000     48790  4.879000e+04     48790     48790.000000
# unique           NaN         9           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33860           NaN     15770              NaN
# mean       38.652798       NaN  1.896690e+05       NaN        10.078807
# std        13.708493       NaN  1.056172e+05       NaN         2.570046
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175550e+05       NaN         9.000000
# 50%        37.000000       NaN  1.781385e+05       NaN        10.000000
# 75%        48.000000       NaN  2.376062e+05       NaN        12.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status      occupation relationship   race gender  \
# ...

# %%
#11. Drop The Columns education-num, capital-gain and capital-loss
df.drop(['capital-loss'],axis=1)
#df.drop(['educational-num'],axis=1)
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 4       18             ?  103497  Some-college       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct    Own-child  Black    Male              40
# ...

# %%
#df.drop(['capital-gain'],axis=1)
#df.drop(['educational-num'],axis=1)

# %%
#12. What Is The Distribution of Age Column Show In Graph?

# %%
df['age'].hist()
plt.title("Distribution of Age column")
plt.show()

# %%
#13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method And Also Without Using Between Method

# %%
#Using Between Method
total_persons=df[df['age'].between(17,48)].shape[1]
print("Total Persons:",total_persons)
# Out:
# Total Persons: 14

# %%
#Without using between method
total_persons=df[(df['age']>=17) &(df['age']<=48)].shape[1]
print("Total Persons:",total_persons)
# Out:
# Total Persons: 14

# %%
#14. What is The Distribution of Workclass Column

# %%
df['workclass'].hist()
plt.title("Distribution of Work Class column")

plt.show()

# %%
#15. How Many Person Having Bachelors or Masters Degree

# %%
#Bachelor's count
bachelor_count=df['education'].eq('Bachelors').sum()
bachelor_count
# Out:
# 8013

# %%
#Masters count
Masters_count=df['education'].eq('Masters').sum()
Masters_count
# Out:
# 2656

# %%
#Create A Boxplot Of The "Income" Column Against The "Age" Column, Segmented By Gender
plt.figure(figsize=(10,6))
sns.boxplot(x='age', y='income', hue='gender',data=df)
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Income Distribution by Age and Gender')
# Out:
# Text(0.5, 1.0, 'Income Distribution by Age and Gender')

# %%
#17Replace income value [<=50k with 0 and >50k with 1]

# %%
#18. Which Workclass getting The Highest Salary

# %%
#19. Who Has Better Chance To Get Salary >50k Male or Female

# %%
#20. Convert Workclass Column DataType To Category Datatype

# %%
df['workclass']=pd.Categorical(df['workclass'])

# %%
df['workclass']

# %%
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# marital-status    object
# occupation        object
# relationship      object
# race              object
# gender            object
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object
